# %%
import sys
import os

sys.path.append('../../../')

from bci_framework.utils import Paradigm
from matplotlib import pyplot as plt

# %%
fig = plt.figure(figsize=(10, 4), dpi=90)


tasks = (

    
)

paradigm = []

paradigm = (
    
      {
        'time': (0, 0, 1),       
        'label': 'Trial instruction',
        'color': 'C5',
        'rotation': 90,
        'label_extra': '',
    },
    
    
    {
        'time': (1, 5),
        'level': (0.5, 1),        
        'label': 'Fixation cross',
        'color': 'C0',
        'marker': {
            'label': 'Auditory signal',
            'label_end': 'Auditory signal',
            'width': 2,
            'level': 1,
        }
    },      
    {
        'time': (1, 5),
        'level': (0, 0.5), 
        'label': 'Trial',
        'color': 'C2',
        'marker': {
            'label': 'Marker streamed',
            'width': 2,
            'level': 2,
        }
    },   
)

Paradigm.build_paradigm(paradigm)
plt.savefig('paradigm.png')

# %% [markdown]
# # Resting state and noise acquisition
#
# Implemented through extensions systems in the [RestingNoiseAcquisition](../../../../_modules/bci_framework.default_extensions.Resting_state_and_noise_acquisition.main.rst) module.
#
# <img src='paradigm.png'></img>
#
# This experiment perforn the same task implemented in <cite data-footcite="cho2017eeg">cho2017eeg</cite>: Resting with open eyes, Resting with close eye, Eye blinking, Eyeball movement up/down, Eyeball movement left/right, Head movement left/right and Jaw clenching. The time acquisition time for each task can be configured independently. The subject can explicitly. The subject can explicitly decide when to continue with the next task with a keyboard event.

# %% [markdown]
# ## Configuration options
#
# <img src='../../../images/extensions/resting_noise.gif'></img>
#
# All tasks have the same configuration option, the acquisition time, from 0 (disabled task) to 5 minutes, 1 minute by default.

# %% [markdown]
# ### References
# .. footbibliography::
